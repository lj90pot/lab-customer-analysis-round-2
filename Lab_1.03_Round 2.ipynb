# %%
import pandas as pd
import numpy as np

# %%
#import data
df1 = pd.read_csv('marketing_customer_analysis.csv')

# %%
df1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
#Here is the shape:
df1.shape
# Out:
# (10910, 26)

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
# ...

# %%
#New names for columns
cols = [col_name.upper().replace(' ', '_') for col_name in df1.columns]
print(cols)
# Out:
# ['UNNAMED:_0', 'CUSTOMER', 'STATE', 'CUSTOMER_LIFETIME_VALUE', 'RESPONSE', 'COVERAGE', 'EDUCATION', 'EFFECTIVE_TO_DATE', 'EMPLOYMENTSTATUS', 'GENDER', 'INCOME', 'LOCATION_CODE', 'MARITAL_STATUS', 'MONTHLY_PREMIUM_AUTO', 'MONTHS_SINCE_LAST_CLAIM', 'MONTHS_SINCE_POLICY_INCEPTION', 'NUMBER_OF_OPEN_COMPLAINTS', 'NUMBER_OF_POLICIES', 'POLICY_TYPE', 'POLICY', 'RENEW_OFFER_TYPE', 'SALES_CHANNEL', 'TOTAL_CLAIM_AMOUNT', 'VEHICLE_CLASS', 'VEHICLE_SIZE', 'VEHICLE_TYPE']

# %%
#Renamed the column names
df1.columns = cols

# %%
df1.head(5)
# Out:
#    UNNAMED:_0 CUSTOMER       STATE  CUSTOMER_LIFETIME_VALUE RESPONSE  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    COVERAGE EDUCATION EFFECTIVE_TO_DATE EMPLOYMENTSTATUS GENDER  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    NUMBER_OF_OPEN_COMPLAINTS NUMBER_OF_POLICIES     POLICY_TYPE        POLICY  \
# ...

# %% [markdown]
# # #Here are if the variables are numerical or categorical
#  0   Unnamed: 0                     10910 non-null  int64  NUMERICAL
#  1   Customer                       10910 non-null  object CATEGORICAL
#  2   State                          10279 non-null  object CATEGORICAL
#  3   Customer Lifetime Value        10910 non-null  float64NUMERICAL
#  4   Response                       10279 non-null  object CATEGORICAL
#  5   Coverage                       10910 non-null  object CATEGORICAL
#  6   Education                      10910 non-null  object CATEGORICAL
#  7   Effective To Date              10910 non-null  object DATE
#  8   EmploymentStatus               10910 non-null  object CATEGORICAL
#  9   Gender                         10910 non-null  object CATEGORICAL
#  10  Income                         10910 non-null  int64  CATEGORICAL
#  11  Location Code                  10910 non-null  object CATEGORICAL
#  12  Marital Status                 10910 non-null  object CATEGORICAL
#  13  Monthly Premium Auto           10910 non-null  int64  NUMERICAL
#  14  Months Since Last Claim        10277 non-null  float64NUMERICAL
#  15  Months Since Policy Inception  10910 non-null  int64  NUMERICAL
#  16  Number of Open Complaints      10277 non-null  float64NUMERICAL
#  17  Number of Policies             10910 non-null  int64  NUMERICAL
#  18  Policy Type                    10910 non-null  object CATEGORICAL
#  19  Policy                         10910 non-null  object CATEGORICAL
#  20  Renew Offer Type               10910 non-null  object CATEGORICAL
#  21  Sales Channel                  10910 non-null  object CATEGORICAL
#  22  Total Claim Amount             10910 non-null  float64NUMERICAL
#  23  Vehicle Class                  10288 non-null  object CATEGORICAL
#  24  Vehicle Size                   10288 non-null  object CATEGORICAL
#  25  Vehicle Type                   5428 non-null   object CATEGORICAL

# %%
#How many NAN are in each columns
df1.isna().sum()
# Out:
# UNNAMED:_0                          0
# CUSTOMER                            0
# STATE                             631
# CUSTOMER_LIFETIME_VALUE             0
# RESPONSE                          631
# COVERAGE                            0
# EDUCATION                           0
# EFFECTIVE_TO_DATE                   0
# EMPLOYMENTSTATUS                    0
# GENDER                              0
# INCOME                              0
# LOCATION_CODE                       0
# MARITAL_STATUS                      0
# MONTHLY_PREMIUM_AUTO                0
# MONTHS_SINCE_LAST_CLAIM           633
# MONTHS_SINCE_POLICY_INCEPTION       0
# NUMBER_OF_OPEN_COMPLAINTS         633
# NUMBER_OF_POLICIES                  0
# POLICY_TYPE                         0
# POLICY                              0
# RENEW_OFFER_TYPE                    0
# SALES_CHANNEL                       0
# TOTAL_CLAIM_AMOUNT                  0
# VEHICLE_CLASS                     622
# VEHICLE_SIZE                      622
# ...

# %%
#Thanks to ISI for the idea to separate the numeric and Strings variables
#Select numeric columns
df_numeric=df1.select_dtypes(include=["float", "int"]) 
null_columns = df_numeric.columns[df_numeric.isna().sum() != 0].tolist()
print(null_columns)
#Put 0 in those which have nulls.
for  Column_to_change in null_columns:
    df_numeric[Column_to_change] = df_numeric[Column_to_change].fillna(0) 
df_numeric.info()
# Out:
# ['MONTHS_SINCE_LAST_CLAIM', 'NUMBER_OF_OPEN_COMPLAINTS']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   UNNAMED:_0                     10910 non-null  int64
#  1   CUSTOMER_LIFETIME_VALUE        10910 non-null  float64
#  2   INCOME                         10910 non-null  int64
#  3   MONTHLY_PREMIUM_AUTO           10910 non-null  int64
#  4   MONTHS_SINCE_LAST_CLAIM        10910 non-null  float64
#  5   MONTHS_SINCE_POLICY_INCEPTION  10910 non-null  int64
#  6   NUMBER_OF_OPEN_COMPLAINTS      10910 non-null  float64
#  7   NUMBER_OF_POLICIES             10910 non-null  int64
#  8   TOTAL_CLAIM_AMOUNT             10910 non-null  float64
# dtypes: float64(4), int64(5)
# memory usage: 767.2 KB

# %%
#Select Object Variables
df_object=df1.select_dtypes(include=["object"]) 
null_columns = df_object.columns[df_object.isna().sum() != 0].tolist()
print(null_columns)
#Put Unkwon in those which have nulls.
for  Column_to_change in null_columns:
    df_object[Column_to_change] = df_object[Column_to_change].fillna('Unknown') 
df_object.info()
# Out:
# ['STATE', 'RESPONSE', 'VEHICLE_CLASS', 'VEHICLE_SIZE', 'VEHICLE_TYPE']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CUSTOMER           10910 non-null  object
#  1   STATE              10910 non-null  object
#  2   RESPONSE           10910 non-null  object
#  3   COVERAGE           10910 non-null  object
#  4   EDUCATION          10910 non-null  object
#  5   EFFECTIVE_TO_DATE  10910 non-null  object
#  6   EMPLOYMENTSTATUS   10910 non-null  object
#  7   GENDER             10910 non-null  object
#  8   LOCATION_CODE      10910 non-null  object
#  9   MARITAL_STATUS     10910 non-null  object
#  10  POLICY_TYPE        10910 non-null  object
#  11  POLICY             10910 non-null  object
#  12  RENEW_OFFER_TYPE   10910 non-null  object
#  13  SALES_CHANNEL      10910 non-null  object
# ...

# %%
#Here is the final dataframe already cleaned
df_clean=pd.concat([df_numeric,df_object],axis=1)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   UNNAMED:_0                     10910 non-null  int64
#  1   CUSTOMER_LIFETIME_VALUE        10910 non-null  float64
#  2   INCOME                         10910 non-null  int64
#  3   MONTHLY_PREMIUM_AUTO           10910 non-null  int64
#  4   MONTHS_SINCE_LAST_CLAIM        10910 non-null  float64
#  5   MONTHS_SINCE_POLICY_INCEPTION  10910 non-null  int64
#  6   NUMBER_OF_OPEN_COMPLAINTS      10910 non-null  float64
#  7   NUMBER_OF_POLICIES             10910 non-null  int64
#  8   TOTAL_CLAIM_AMOUNT             10910 non-null  float64
#  9   CUSTOMER                       10910 non-null  object
#  10  STATE                          10910 non-null  object
#  11  RESPONSE                       10910 non-null  object
# ...

# %%
df_clean.isna().sum()
# Out:
# UNNAMED:_0                       0
# CUSTOMER_LIFETIME_VALUE          0
# INCOME                           0
# MONTHLY_PREMIUM_AUTO             0
# MONTHS_SINCE_LAST_CLAIM          0
# MONTHS_SINCE_POLICY_INCEPTION    0
# NUMBER_OF_OPEN_COMPLAINTS        0
# NUMBER_OF_POLICIES               0
# TOTAL_CLAIM_AMOUNT               0
# CUSTOMER                         0
# STATE                            0
# RESPONSE                         0
# COVERAGE                         0
# EDUCATION                        0
# EFFECTIVE_TO_DATE                0
# EMPLOYMENTSTATUS                 0
# GENDER                           0
# LOCATION_CODE                    0
# MARITAL_STATUS                   0
# POLICY_TYPE                      0
# POLICY                           0
# RENEW_OFFER_TYPE                 0
# SALES_CHANNEL                    0
# VEHICLE_CLASS                    0
# VEHICLE_SIZE                     0
# VEHICLE_TYPE                     0
# dtype: int64

# %%
#Change the data type for the date 
df_time=df_clean
df_time['EFFECTIVE_TO_DATE'] = pd.to_datetime(df_time['EFFECTIVE_TO_DATE'])

# %%
df_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   UNNAMED:_0                     10910 non-null  int64
#  1   CUSTOMER_LIFETIME_VALUE        10910 non-null  float64
#  2   INCOME                         10910 non-null  int64
#  3   MONTHLY_PREMIUM_AUTO           10910 non-null  int64
#  4   MONTHS_SINCE_LAST_CLAIM        10910 non-null  float64
#  5   MONTHS_SINCE_POLICY_INCEPTION  10910 non-null  int64
#  6   NUMBER_OF_OPEN_COMPLAINTS      10910 non-null  float64
#  7   NUMBER_OF_POLICIES             10910 non-null  int64
#  8   TOTAL_CLAIM_AMOUNT             10910 non-null  float64
#  9   CUSTOMER                       10910 non-null  object
#  10  STATE                          10910 non-null  object
#  11  RESPONSE                       10910 non-null  object
# ...

# %%
#Extract month from date
df_time['MONTH'] = df_time['EFFECTIVE_TO_DATE'].dt.month
df_time
# Out:
#        UNNAMED:_0  CUSTOMER_LIFETIME_VALUE  INCOME  MONTHLY_PREMIUM_AUTO  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        MONTHS_SINCE_LAST_CLAIM  MONTHS_SINCE_POLICY_INCEPTION  \
# ...

# %%
#explore dates
df_time_2 = df_time[df_time['EFFECTIVE_TO_DATE'] < '2011-01-01' ]
df_time_2

# %%
df_time['MONTH'].value_counts()
# Out:
# 1    5818
# 2    5092
# Name: MONTH, dtype: int64

# %%
#Filter only records in First quarter. Also only months 1,2 and 3
df_time_2=df_time[df_time['MONTH'].isin([1,2,3])]
df_time_2
# Out:
#        UNNAMED:_0  CUSTOMER_LIFETIME_VALUE  INCOME  MONTHLY_PREMIUM_AUTO  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        MONTHS_SINCE_LAST_CLAIM  MONTHS_SINCE_POLICY_INCEPTION  \
# ...

# %% [markdown]
# # Here starts the extra excercise

# %%
#Function to clean the data
def DATA_FRAME_CLEAN(data_frame_input):
    #Standarize column names
    cols = [col_name.upper().replace(' ', '_') for col_name in data_frame_input.columns]
    data_frame_input.columns = cols
    
    #Thanks to ISI for the idea to separate the numeric and Strings variables
    #Clean nulls
    #Select numeric columns
    df_numeric=data_frame_input.select_dtypes(include=["float", "int"]) 
    null_columns = df_numeric.columns[df_numeric.isna().sum() != 0].tolist()
    print(null_columns)
    #Put 0 in those which have nulls.
    for  Column_to_change in null_columns:
        df_numeric[Column_to_change] = df_numeric[Column_to_change].fillna(0) 
    
    #Select Object Variables
    df_object=data_frame_input.select_dtypes(include=[object]) 
    null_columns = df_object.columns[df_object.isna().sum() != 0].tolist()
    print(null_columns)
    #Put Unkwon in those which have nulls.
    for  Column_to_change in null_columns:
        df_object[Column_to_change] = df_object[Column_to_change].fillna('Unknown') 
    
    #Merge both branches
    data_frame_input=pd.concat([df_numeric,df_object],axis=1)
    print(data_frame_input.columns)
    
    #Change EFFECTIVE_TO_DATE to date type
    data_frame_input['EFFECTIVE_TO_DATE'] = pd.to_datetime(data_frame_input['EFFECTIVE_TO_DATE'])
    
    #Assign to ouput
    data_frame_output=data_frame_input
    
    return data_frame_output

# %%
#Input the dataframe to clean
data_frame_input = pd.read_csv('marketing_customer_analysis.csv')
data_good=DATA_FRAME_CLEAN(data_frame_input)
data_good
# Out:
# ['MONTHS_SINCE_LAST_CLAIM', 'NUMBER_OF_OPEN_COMPLAINTS']
# ['STATE', 'RESPONSE', 'VEHICLE_CLASS', 'VEHICLE_SIZE', 'VEHICLE_TYPE']
# Index(['UNNAMED:_0', 'CUSTOMER_LIFETIME_VALUE', 'INCOME',
#        'MONTHLY_PREMIUM_AUTO', 'MONTHS_SINCE_LAST_CLAIM',
#        'MONTHS_SINCE_POLICY_INCEPTION', 'NUMBER_OF_OPEN_COMPLAINTS',
#        'NUMBER_OF_POLICIES', 'TOTAL_CLAIM_AMOUNT', 'CUSTOMER', 'STATE',
#        'RESPONSE', 'COVERAGE', 'EDUCATION', 'EFFECTIVE_TO_DATE',
#        'EMPLOYMENTSTATUS', 'GENDER', 'LOCATION_CODE', 'MARITAL_STATUS',
#        'POLICY_TYPE', 'POLICY', 'RENEW_OFFER_TYPE', 'SALES_CHANNEL',
#        'VEHICLE_CLASS', 'VEHICLE_SIZE', 'VEHICLE_TYPE'],
#       dtype='object')
#        UNNAMED:_0  CUSTOMER_LIFETIME_VALUE  INCOME  MONTHLY_PREMIUM_AUTO  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# ...
